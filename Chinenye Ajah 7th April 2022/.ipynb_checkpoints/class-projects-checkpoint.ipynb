# %% [markdown]
# ## Chinenye Ajah
# ### 21120612446
# ##### chinenye.ajah@pau.edu.ng

# %% [markdown]
# ### Project 1

# %% [markdown]
# #### Pseudocode for Project 1
# #####  STEP1 Start
# ##### STEP 2 INPUT n
# ##### STEP 3 COMPUTE Ans =n - 17
# ##### STEP 4 IF n > 17
# ##### STEP 5 COMPUTE 2*Ans
# ##### STEP 6 PRINT  2*Ans
# ##### STEP 7 ELSE COMPUTE
# ##### STEP 8 Stop

# %% [markdown]
# ![Picture1.jpg](attachment:Picture1.jpg)

# %%
#code for project one
n= int(input("enter number : "))
Ans = x-17
if n>17:
    print(Ans*2)
elif n <17:
    print(abs(n))

# %% [markdown]
# #### Project 2
# ##### Pseudocode for Project 2
# ##### STEP 1 Start
# ##### STEP 2 INPUT X
# ##### STEP 3 INPUT Y
# ##### STEP 4 INPUT Z
# ##### STEP 5 IF X=Y=Z
# ##### STEP 6 PRINT 3*(X+Y+Z)
# ##### STEP 7 ELSE PRINT X+Y+Z
# ##### STEP 8 Stop

# %% [markdown]
# ![Picture2.jpg](attachment:Picture2.jpg)

# %%
#Code for Project 2
x =int(input("Input number: "))
y =int(input("Input number: "))
z =int(input("Input number: "))
d = x+y+z
if x==y and y==z and z==x:
    print(3*(x+y+z))
else:
    print(x+y+z)

# %% [markdown]
# #### Project 3
# #### Pseudocode for Project 3
# ##### STEP 1 Start
# ##### STEP 2 INPUT a
# ##### STEP 3 INPUT b
# ##### STEP 4 IF a=b
# ##### STEP 5 PRINT True
# ##### STEP 6 ELIF a+b=5
# ##### STEP 7 PRINT True
# ##### STEP 8 ELIF a-b=5
# ##### STEP 9 PRINT True
# ##### STEP 10 ELSE FALSE
# ##### STEP 11 Stop

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %%
#Code for Project 3
a =int(input("Input number: "))
b =int(input("Input number: "))
if a==b:
    print(True)
elif a+b ==5:
    print(True)
elif a-b ==5:
    print(True)
else:
    print(False)

# %% [markdown]
# #### Project 4
# #### Pseudocode for Project 4
# ##### STEP 1 Start
# ##### STEP 2 INPUT first number as maximum
# ##### STEP 3 INPUT second number as middle
# ##### STEP 4 INPUT third number as minimum
# ##### STEP 5 COMPUTE (minimum+middle+maximum)-miminum-maximum
# ##### STEP 6 PRINT maximum number
# ##### STEP 7 PRINT middle number
# ##### STEP 8 PRINT minimum number
# ##### STEP 9 Stop

# %% [markdown]
# ![Picture%204.jpg](attachment:Picture%204.jpg)

# %%
#Code for Project 4
n1 =int(input("Input number: "))
n2 =int(input("Input number: "))
n3 =int(input("Input number: ")) 
list=[n1,n2,n3]
list.sort()
a= list[0]
b= list[1]
c= list[2]
print("The smallest number is ", a)
print("The middle  number is ", b)
print("The biggest number is ", c)

# %% [markdown]
# #### Project 5
# #### Pseudocode for Project 5
# ##### STEP 1 Start
# ##### STEP 2 INPUT number
# ##### STEP 3 IF number is positive
# ##### STEP 4 PRINT Sum of cube of positive numbers below the given number
# ##### STEP 5 ELSE PRINT This function cannot be carried out
# ##### STEP 6 STOP

# %% [markdown]
# ![Picture5.jpg](attachment:Picture5.jpg)

# %%
#Code for Project 5
newlist = []
n =int(input("Please input number"))
while n>1:
    n -= 1
    Cube=(n**3)
    print(Cube)
    newlist.append(Cube)
    print(sum(newlist))
