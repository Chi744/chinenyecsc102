# %%
#Project 2 code 
def uses_all():
    word=input("Please input word")
    required="aeiouAEIOU"
    if required in word:
        print(True)
    else:
        print(False)
uses_all()

# %% [markdown]
# ###Flowchart for Project 2
# ![Project%20II.png](attachment:Project%20II.png)

# %%
###Pseudocode for Project 2
### STEP 1 Start
### STEP 2 INPUT Word
### STEP 3 
### STEP 4
### STEP 5
### 
###

# %%
# Code for Project 3
import math
q = str(input("Player 1, pick between even and odd"))
w = str(input("Player 2, pick between even and odd"))

e = int(input("Player 1, pick a number"))
r = int(input("Player 2 , pick a number"))

f=0
if (e+r)%2 == 0 :
    f = 1
else:
    f = 2
if f == 1:
    if q == "EVEN":
        print("Player 1 is correct")
    elif w == "EVEN"
        print("Player 2 is correct")
    elif q and w =="EVEN"
        print("Both players are correct")
    elif q and w != "EVEN":
        print("Bot")
elif f == 2:
    if q =="ODD":
        print("Player 1 is correct")
    elif w == "ODD":
        print("Player 2 is correct")
    elif q and w == "ODD":
        print("Both players are correct")

# %%
###Pseudocode for Project 3

# %%
###Flowchart for Project 3

# %%
#Code for Project 4

# %%
###Pseudocode for Project 4

# %%
###Flowchart for Project 4

# %%
#Code for Project 1

# %%
###Pseudocode for Project 1

# %%
###Flowchart for Project 1
